# %%
import pandas as pd# For data analysis and manipulation
import numpy as np# For numerical and mathematical computations
import matplotlib.pyplot as plt# For creating visualizations and graphs
import seaborn as sns# For creating attractive and informative statistical graphics
import warnings# For managing warning messages during code execution

# %%
data = pd.read_csv("D:\\UncleanData.csv") 
data.head()
data
# Out:
#         Reservoir_name     SUBDIVISION    JUN    JUL    AUG    SEP  \
# 0     Aliyar Reservoir      Tamil Nadu   29.7   58.7   62.3  124.8
# 1     Aliyar Reservoir      Tamil Nadu   37.9   37.6   98.4  132.2
# 2     Aliyar Reservoir      Tamil Nadu   66.4  117.7   82.9  133.0
# 3     Aliyar Reservoir      Tamil Nadu   34.5  168.6  125.5   94.7
# 4     Aliyar Reservoir      Tamil Nadu   72.4   45.1  155.7  163.5
# ...                ...             ...    ...    ...    ...    ...
# 3529            Yeleru  Andhra Pradesh   99.7  181.3  149.5  264.0
# 3530            Yeleru  Andhra Pradesh   94.4  151.2  148.3  135.7
# 3531            Yeleru  Andhra Pradesh  147.0  188.1  264.1  259.2
# 3532            Yeleru  Andhra Pradesh   89.1  219.0  123.1  154.8
# 3533            Yeleru  Andhra Pradesh  105.1  198.6  179.3   88.6
#
#       June-September Temperature Min Temperature Max pH Min pH Max  \
# 0              275.5              26              30      7      7
# ...

# %%
data.shape
# Out:
# (3534, 15)

# %%
data.columns
# Out:
# Index(['Reservoir_name', 'SUBDIVISION', 'JUN', 'JUL', 'AUG', 'SEP',
#        'June-September', 'Temperature Min', 'Temperature Max', 'pH Min',
#        'pH Max', 'Full_reservoir_level', 'Live_capacity_FRL', 'Storage',
#        'Level'],
#       dtype='object')

# %%
data.head()
# Out:
#      Reservoir_name SUBDIVISION   JUN    JUL    AUG    SEP  June-September  \
# 0  Aliyar Reservoir  Tamil Nadu  29.7   58.7   62.3  124.8           275.5
# 1  Aliyar Reservoir  Tamil Nadu  37.9   37.6   98.4  132.2           306.1
# 2  Aliyar Reservoir  Tamil Nadu  66.4  117.7   82.9  133.0           400.0
# 3  Aliyar Reservoir  Tamil Nadu  34.5  168.6  125.5   94.7           423.3
# 4  Aliyar Reservoir  Tamil Nadu  72.4   45.1  155.7  163.5           436.7
#
#   Temperature Min Temperature Max pH Min pH Max  Full_reservoir_level  \
# 0              26              30      7      7                320.04
# 1              29              29      7      7                320.04
# 2              29              29      7      8                320.04
# 3              31              31      6      6                320.04
# 4              25              31      7      7                320.04
#
#    Live_capacity_FRL  Storage    Level
# 0              0.095  0.00810  303.505
# ...

# %%
data.tail()
# Out:
#      Reservoir_name     SUBDIVISION    JUN    JUL    AUG    SEP  \
# 3529         Yeleru  Andhra Pradesh   99.7  181.3  149.5  264.0
# 3530         Yeleru  Andhra Pradesh   94.4  151.2  148.3  135.7
# 3531         Yeleru  Andhra Pradesh  147.0  188.1  264.1  259.2
# 3532         Yeleru  Andhra Pradesh   89.1  219.0  123.1  154.8
# 3533         Yeleru  Andhra Pradesh  105.1  198.6  179.3   88.6
#
#       June-September Temperature Min Temperature Max pH Min pH Max  \
# 3529           694.5              23              27      7      7
# 3530           529.6              28              28      7      7
# 3531           858.4
# 3532           586.0              24              24      7      7
# 3533           571.6              22              23      7      7
#
#       Full_reservoir_level  Live_capacity_FRL  Storage   Level
# 3529                 86.56              0.508      NaN     NaN
# 3530                 86.56              0.508      NaN  71.421
# ...

# %%
data.describe()
# Out:
#                JUN          JUL          AUG         SEP  June-September  \
# count  3472.000000  3534.000000  3534.000000  3534.00000     3534.000000
# mean    205.664631   340.732852   273.574759   180.35863      984.668846
# std     218.896211   248.570939   170.646836   105.41493      615.208665
# min       0.400000     3.200000     0.600000     0.20000       57.400000
# 25%      75.875000   188.700000   150.550000   104.40000      596.700000
# 50%     132.700000   288.700000   245.300000   168.10000      854.150000
# 75%     222.700000   411.900000   370.600000   241.10000     1176.500000
# max    1361.600000  1904.900000  1579.100000   716.50000     4537.000000
#
#        Full_reservoir_level  Live_capacity_FRL      Storage        Level
# count           3502.000000        3534.000000  2508.000000  2526.000000
# mean             378.636999           1.453247     0.433715   402.220783
# std              244.842440           1.850915     0.539920   237.469036
# ...

# %%
data.max()
# Out:
# Reservoir_name               Yeleru
# SUBDIVISION             West Bengal
# JUN                          1361.6
# JUL                          1904.9
# AUG                          1579.1
# SEP                           716.5
# June-September               4537.0
# Temperature Min                 999
# Temperature Max                   9
# pH Min                            9
# pH Max                            9
# Full_reservoir_level        1002.79
# Live_capacity_FRL             9.745
# Storage                       5.233
# Level                        970.38
# dtype: object

# %%
data.min()
# Out:
# Reservoir_name          Aliyar Reservoir
# SUBDIVISION                    Karnataka
# JUN                                  0.4
# JUL                                  3.2
# AUG                                  0.6
# SEP                                  0.2
# June-September                      57.4
# Temperature Min
# Temperature Max
# pH Min
# pH Max
# Full_reservoir_level                 5.7
# Live_capacity_FRL                  0.006
# Storage                          0.00006
# Level                              47.73
# dtype: object

# %%
df=data.copy()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3534 entries, 0 to 3533
# Data columns (total 15 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Reservoir_name        3534 non-null   object
#  1   SUBDIVISION           3534 non-null   object
#  2   JUN                   3472 non-null   float64
#  3   JUL                   3534 non-null   float64
#  4   AUG                   3534 non-null   float64
#  5   SEP                   3534 non-null   float64
#  6   June-September        3534 non-null   float64
#  7   Temperature Min       3534 non-null   object
#  8   Temperature Max       3534 non-null   object
#  9   pH Min                3534 non-null   object
#  10  pH Max                3534 non-null   object
#  11  Full_reservoir_level  3502 non-null   float64
#  12  Live_capacity_FRL     3534 non-null   float64
#  13  Storage               2508 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# Reservoir_name             0
# SUBDIVISION                0
# JUN                       62
# JUL                        0
# AUG                        0
# SEP                        0
# June-September             0
# Temperature Min            0
# Temperature Max            0
# pH Min                     0
# pH Max                     0
# Full_reservoir_level      32
# Live_capacity_FRL          0
# Storage                 1026
# Level                   1008
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# 0

# %%
# Load dataset
df = pd.read_csv("D:\\UncleanData.csv")
# Create plots
plt.figure(figsize=(12, 4))
# Histogram
plt.subplot(1, 2, 1)
sns.histplot(df["Storage"], bins=20, color="darkgreen")
plt.title("Histogram of Storage")
plt.xlabel("Storage")
plt.ylabel("Frequency")

# Box Plot
plt.subplot(1, 2, 2)
sns.boxplot(y=df["Storage"], color="darkblue", boxprops={"facecolor": "none"})
plt.title("Box Plot of Storage")
plt.ylabel("Storage")
# Show plots
plt.tight_layout()
plt.show()

# %%
# Load dataset
df = pd.read_csv("D:\\UncleanData.csv")

# Create plots
plt.figure(figsize=(12, 4))

# Histogram
plt.subplot(1, 2, 1)
sns.histplot(df["Level"], bins=20, color="darkgreen")
plt.title("Histogram of Level")
plt.xlabel("Level")
plt.ylabel("Frequency")

# Box Plot
plt.subplot(1, 2, 2)
sns.boxplot(y=df["Level"], color="darkblue", boxprops={"facecolor": "none"})
plt.title("Box Plot of Level")
plt.ylabel("Level")

# Show plots
plt.tight_layout()
plt.show()

# %%
# Load dataset
df = pd.read_csv("D:\\UncleanData.csv")

# Create subplots
plt.figure(figsize=(12, 4))

# Histogram
plt.subplot(1, 2, 1)
sns.histplot(df["JUN"], bins=20, color="darkgreen")
plt.title("Histogram of JUN")
plt.xlabel("JUN")
plt.ylabel("Frequency")

# Box Plot
plt.subplot(1, 2, 2)
sns.boxplot(y=df["JUN"], color="darkblue", boxprops={"facecolor": "none"})
plt.title("Box Plot of JUN")
plt.ylabel("JUN")

# Show plots
plt.tight_layout()
plt.show()

# %%
# Load dataset
df = pd.read_csv("D:\\UncleanData.csv")

# Create subplots
plt.figure(figsize=(12, 5))

# Histogram
plt.subplot(1, 2, 1)
sns.histplot(df["Full_reservoir_level"], bins=20, color="darkgreen")
plt.title("Histogram of Full Reservoir Level")
plt.xlabel("Full Reservoir Level")
plt.ylabel("Frequency")

# Box Plot
plt.subplot(1, 2, 2)
sns.boxplot(y=df["Full_reservoir_level"], color="darkblue", boxprops={"facecolor": "none"})
plt.title("Box Plot of Full Reservoir Level")
plt.ylabel("Full Reservoir Level")

# Show plots
plt.tight_layout()
plt.show()

# %%
df.duplicated().sum()

# %%
# Sample DataFrame (Ensure df is defined)
df = pd.DataFrame(columns=['Full_reservoir_level', 'Jun', 'Level', 'Storage'])
# Fill null values with column mean
df = df.fillna(df.mean())
# Grouped average calculations similar to bmi_avg_value
jun_avg_value = df.groupby(['Full_reservoir_level'])['Jun'].mean().reset_index()
full_reservoir_level_avg = df.groupby(['Jun'])['Full_reservoir_level'].mean().reset_index()
storage_avg_value = df.groupby(['Level'])['Storage'].mean().reset_index()
level_avg_value = df.groupby(['Storage'])['Level'].mean().reset_index()

# %%
df.isnull().sum()
# Out:
# Full_reservoir_level    0
# Jun                     0
# Level                   0
# Storage                 0
# dtype: int64

# %%
# Load and clean data
file_path = "D:\\UncleanData.csv"  
df = pd.read_csv(file_path)
df.columns = df.columns.str.strip()

# Set up the full figure
plt.figure(figsize=(20, 24))
plt.subplots_adjust(hspace=0.5)

# Plot 1
plt.subplot(5, 2, 1)
sns.boxplot(x="SUBDIVISION", y="Live_capacity_FRL", data=df, showfliers=True)
plt.xticks(rotation=45, ha="right")
plt.title("Live_capacity_FRL vs. SUBDIVISION")
plt.xlabel("SUBDIVISION")
plt.ylabel("Live_capacity_FRL")
plt.grid(True, linestyle="--", alpha=0.5)

# Plot 2
plt.subplot(5, 2, 2)
sns.boxplot(x="SUBDIVISION", y="JUL", data=df, showfliers=True)
plt.xticks(rotation=45, ha="right")
plt.title("JUL vs. SUBDIVISION")
plt.xlabel("SUBDIVISION")
plt.ylabel("JUL")
plt.grid(True, linestyle="--", alpha=0.5)

# Plot 3
plt.subplot(5, 2, 3)
sns.boxplot(x="SUBDIVISION", y="AUG", data=df, showfliers=True)
plt.xticks(rotation=45, ha="right")
plt.title("AUG vs. SUBDIVISION")
plt.xlabel("SUBDIVISION")
plt.ylabel("AUG")
plt.grid(True, linestyle="--", alpha=0.5)

# Plot 4
plt.subplot(5, 2, 4)
sns.boxplot(x="SUBDIVISION", y="SEP", data=df, showfliers=True)
plt.xticks(rotation=45, ha="right")
plt.title("SEP vs. SUBDIVISION")
plt.xlabel("SUBDIVISION")
plt.ylabel("SEP")
plt.grid(True, linestyle="--", alpha=0.5)

# Plot 5
plt.subplot(5, 2, 5)
sns.boxplot(x="SUBDIVISION", y="June-September", data=df, showfliers=True)
plt.xticks(rotation=45, ha="right")
plt.title("June-September vs. SUBDIVISION")
plt.xlabel("SUBDIVISION")
plt.ylabel("June-September")
plt.grid(True, linestyle="--", alpha=0.5)

# Plot 6
plt.subplot(5, 2, 6)
sns.boxplot(x="SUBDIVISION", y="Temperature Min", data=df, showfliers=True)
plt.xticks(rotation=45, ha="right")
plt.title("Temperature Min vs. SUBDIVISION")
plt.xlabel("SUBDIVISION")
plt.ylabel("Temperature Min")
plt.grid(True, linestyle="--", alpha=0.5)

# Plot 7
plt.subplot(5, 2, 7)
sns.boxplot(x="SUBDIVISION", y="Temperature Max", data=df, showfliers=True)
plt.xticks(rotation=45, ha="right")
plt.title("Temperature Max vs. SUBDIVISION")
plt.xlabel("SUBDIVISION")
plt.ylabel("Temperature Max")
plt.grid(True, linestyle="--", alpha=0.5)

# Plot 8
plt.subplot(5, 2, 8)
sns.boxplot(x="SUBDIVISION", y="pH Min", data=df, showfliers=True)
plt.xticks(rotation=45, ha="right")
plt.title("pH Min vs. SUBDIVISION")
plt.xlabel("SUBDIVISION")
plt.ylabel("pH Min")
plt.grid(True, linestyle="--", alpha=0.5)

# Plot 9
plt.subplot(5, 2, 9)
sns.boxplot(x="SUBDIVISION", y="pH Max", data=df, showfliers=True)
plt.xticks(rotation=45, ha="right")
plt.title("pH Max vs. SUBDIVISION")
plt.xlabel("SUBDIVISION")
plt.ylabel("pH Max")
plt.grid(True, linestyle="--", alpha=0.5)

# Show all plots
plt.tight_layout()
plt.show()

# %%
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns

# Load dataset
df = pd.read_csv("D:\\UncleanData.csv")
df.columns = df.columns.str.strip()  # Clean column names

# Convert all columns to numeric, forcing errors to NaN
df = df.apply(pd.to_numeric, errors='coerce')

# List of variables to plot
variables = [
    "Live_capacity_FRL", "JUL", "AUG", "Storage", "Level", "Full_reservoir_level", "JUN",
    "SEP", "June-September", "Temperature Min", "Temperature Max", "pH Min", "pH Max"
]

# Set up figure
plt.figure(figsize=(20, 30))
plt.subplots_adjust(hspace=0.6)

# Plot each variable individually after outlier filtering
Q1, Q3 = df["Live_capacity_FRL"].quantile([0.25, 0.75])
IQR = Q3 - Q1
filtered_df = df[(df["Live_capacity_FRL"] >= Q1 - 1.5 * IQR) & (df["Live_capacity_FRL"] <= Q3 + 1.5 * IQR)]
plt.subplot(7, 2, 1)
sns.boxplot(y=filtered_df["Live_capacity_FRL"], color="darkblue", showfliers=False)
plt.title("Box Plot of Live_capacity_FRL (Without Outliers)")
plt.ylabel("Live_capacity_FRL")
plt.grid(True, linestyle="--", alpha=0.5)

Q1, Q3 = df["JUL"].quantile([0.25, 0.75])
IQR = Q3 - Q1
filtered_df = df[(df["JUL"] >= Q1 - 1.5 * IQR) & (df["JUL"] <= Q3 + 1.5 * IQR)]
plt.subplot(7, 2, 2)
sns.boxplot(y=filtered_df["JUL"], color="darkblue", showfliers=False)
plt.title("Box Plot of JUL (Without Outliers)")
plt.ylabel("JUL")
plt.grid(True, linestyle="--", alpha=0.5)

Q1, Q3 = df["AUG"].quantile([0.25, 0.75])
IQR = Q3 - Q1
filtered_df = df[(df["AUG"] >= Q1 - 1.5 * IQR) & (df["AUG"] <= Q3 + 1.5 * IQR)]
plt.subplot(7, 2, 3)
sns.boxplot(y=filtered_df["AUG"], color="darkblue", showfliers=False)
plt.title("Box Plot of AUG (Without Outliers)")
plt.ylabel("AUG")
plt.grid(True, linestyle="--", alpha=0.5)

Q1, Q3 = df["Storage"].quantile([0.25, 0.75])
IQR = Q3 - Q1
filtered_df = df[(df["Storage"] >= Q1 - 1.5 * IQR) & (df["Storage"] <= Q3 + 1.5 * IQR)]
plt.subplot(7, 2, 4)
sns.boxplot(y=filtered_df["Storage"], color="darkblue", showfliers=False)
plt.title("Box Plot of Storage (Without Outliers)")
plt.ylabel("Storage")
plt.grid(True, linestyle="--", alpha=0.5)

Q1, Q3 = df["Level"].quantile([0.25, 0.75])
IQR = Q3 - Q1
filtered_df = df[(df["Level"] >= Q1 - 1.5 * IQR) & (df["Level"] <= Q3 + 1.5 * IQR)]
plt.subplot(7, 2, 5)
sns.boxplot(y=filtered_df["Level"], color="darkblue", showfliers=False)
plt.title("Box Plot of Level (Without Outliers)")
plt.ylabel("Level")
plt.grid(True, linestyle="--", alpha=0.5)

Q1, Q3 = df["Full_reservoir_level"].quantile([0.25, 0.75])
IQR = Q3 - Q1
filtered_df = df[(df["Full_reservoir_level"] >= Q1 - 1.5 * IQR) & (df["Full_reservoir_level"] <= Q3 + 1.5 * IQR)]
plt.subplot(7, 2, 6)
sns.boxplot(y=filtered_df["Full_reservoir_level"], color="darkblue", showfliers=False)
plt.title("Box Plot of Full_reservoir_level (Without Outliers)")
plt.ylabel("Full_reservoir_level")
plt.grid(True, linestyle="--", alpha=0.5)

Q1, Q3 = df["JUN"].quantile([0.25, 0.75])
IQR = Q3 - Q1
filtered_df = df[(df["JUN"] >= Q1 - 1.5 * IQR) & (df["JUN"] <= Q3 + 1.5 * IQR)]
plt.subplot(7, 2, 7)
sns.boxplot(y=filtered_df["JUN"], color="darkblue", showfliers=False)
plt.title("Box Plot of JUN (Without Outliers)")
plt.ylabel("JUN")
plt.grid(True, linestyle="--", alpha=0.5)

Q1, Q3 = df["SEP"].quantile([0.25, 0.75])
IQR = Q3 - Q1
filtered_df = df[(df["SEP"] >= Q1 - 1.5 * IQR) & (df["SEP"] <= Q3 + 1.5 * IQR)]
plt.subplot(7, 2, 8)
sns.boxplot(y=filtered_df["SEP"], color="darkblue", showfliers=False)
plt.title("Box Plot of SEP (Without Outliers)")
plt.ylabel("SEP")
plt.grid(True, linestyle="--", alpha=0.5)

Q1, Q3 = df["June-September"].quantile([0.25, 0.75])
IQR = Q3 - Q1
filtered_df = df[(df["June-September"] >= Q1 - 1.5 * IQR) & (df["June-September"] <= Q3 + 1.5 * IQR)]
plt.subplot(7, 2, 9)
sns.boxplot(y=filtered_df["June-September"], color="darkblue", showfliers=False)
plt.title("Box Plot of June-September (Without Outliers)")
plt.ylabel("June-September")
plt.grid(True, linestyle="--", alpha=0.5)

Q1, Q3 = df["Temperature Min"].quantile([0.25, 0.75])
IQR = Q3 - Q1
filtered_df = df[(df["Temperature Min"] >= Q1 - 1.5 * IQR) & (df["Temperature Min"] <= Q3 + 1.5 * IQR)]
plt.subplot(7, 2, 10)
sns.boxplot(y=filtered_df["Temperature Min"], color="darkblue", showfliers=False)
plt.title("Box Plot of Temperature Min (Without Outliers)")
plt.ylabel("Temperature Min")
plt.grid(True, linestyle="--", alpha=0.5)

Q1, Q3 = df["Temperature Max"].quantile([0.25, 0.75])
IQR = Q3 - Q1
filtered_df = df[(df["Temperature Max"] >= Q1 - 1.5 * IQR) & (df["Temperature Max"] <= Q3 + 1.5 * IQR)]
plt.subplot(7, 2, 11)
sns.boxplot(y=filtered_df["Temperature Max"], color="darkblue", showfliers=False)
plt.title("Box Plot of Temperature Max (Without Outliers)")
plt.ylabel("Temperature Max")
plt.grid(True, linestyle="--", alpha=0.5)

Q1, Q3 = df["pH Min"].quantile([0.25, 0.75])
IQR = Q3 - Q1
filtered_df = df[(df["pH Min"] >= Q1 - 1.5 * IQR) & (df["pH Min"] <= Q3 + 1.5 * IQR)]
plt.subplot(7, 2, 12)
sns.boxplot(y=filtered_df["pH Min"], color="darkblue", showfliers=False)
plt.title("Box Plot of pH Min (Without Outliers)")
plt.ylabel("pH Min")
plt.grid(True, linestyle="--", alpha=0.5)

Q1, Q3 = df["pH Max"].quantile([0.25, 0.75])
IQR = Q3 - Q1
filtered_df = df[(df["pH Max"] >= Q1 - 1.5 * IQR) & (df["pH Max"] <= Q3 + 1.5 * IQR)]
plt.subplot(7, 2, 13)
sns.boxplot(y=filtered_df["pH Max"], color="darkblue", showfliers=False)
plt.title("Box Plot of pH Max (Without Outliers)")
plt.ylabel("pH Max")
plt.grid(True, linestyle="--", alpha=0.5)

# Show all boxplots
plt.tight_layout()
plt.show()

# %%
file_path = "D:\\UncleanData.csv"  
df = pd.read_csv(file_path)
df.columns = df.columns.str.strip()

# If multiple entries per subdivision, group and take average
avg_levels = df.groupby('SUBDIVISION')['Level'].mean().reset_index()

plt.figure(figsize=(12, 6))
sns.lineplot(x="SUBDIVISION", y="Level", data=avg_levels, marker='o', color='purple')

plt.xticks(rotation=45, ha="right")  
plt.xlabel("SUBDIVISION")
plt.ylabel("Average Level")
plt.title("Average Level across SUBDIVISIONS (Line Graph)")
plt.grid(True, linestyle="--", alpha=0.5)

plt.tight_layout()
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = pd.read_csv("D:\\UncleanData.csv")
data.columns = data.columns.str.strip()

months = ["JUN", "JUL", "AUG", "SEP"]
rainfall = data[months].sum()  # Summing up rainfall across all reservoirs

plt.pie(rainfall, labels=months, autopct='%1.1f%%', startangle=90)
plt.title("Rain Data Set")
plt.show()

# %%
data = pd.read_csv("D:\\UncleanData.csv")
data.columns = data.columns.str.strip()
numeric_cols = ["Temperature Min", "Temperature Max", "pH Min", "pH Max"]
for col in numeric_cols:
    data[col] = pd.to_numeric(data[col], errors="coerce") 
data = data.dropna(subset=numeric_cols)
heatmap_data = data.pivot_table(index="SUBDIVISION", values=numeric_cols, aggfunc="mean") 
plt.figure(figsize=(10, 6))
sns.heatmap(heatmap_data, cmap="coolwarm", annot=True, fmt=".2f", linewidths=0.5)
plt.title("Subdivision-wise Temperature and pH Levels")
plt.xlabel("Parameters")
plt.ylabel("Subdivision")
plt.xticks(rotation=45, ha="right")
plt.yticks(rotation=0)
plt.tight_layout()
plt.show()

# %%
df = pd.read_csv("D:\\UncleanData.csv")
df.columns = df.columns.str.strip()
numeric_df = df.select_dtypes(include=["number"])
corr = numeric_df.corr()
plt.figure(figsize=(8, 6))
sns.heatmap(corr, annot=True, cmap="coolwarm", mask=np.triu(corr), linewidths=0.5, fmt=".2f")
plt.title("Correlation Heatmap")
plt.show()

# %%
df = pd.read_csv("D:\\UncleanData.csv")
df.columns = df.columns.str.strip()
columns_needed = ["SUBDIVISION", "Reservoir_name", "Temperature Min", "Temperature Max"]
df = df[columns_needed].dropna()

df[["Temperature Min", "Temperature Max"]] = df[["Temperature Min", "Temperature Max"]].apply(pd.to_numeric, errors="coerce")

for state, state_data in df.groupby("SUBDIVISION"):
    plt.figure(figsize=(10, 5))
    plt.plot(state_data["Reservoir_name"], state_data["Temperature Min"], marker="o", color="blue", label="Min Temperature")
    plt.plot(state_data["Reservoir_name"], state_data["Temperature Max"], marker="s", color="red", label="Max Temperature")

    plt.title(f"Temperature Variation in {state}", fontsize=14, fontweight="bold")
    plt.xlabel("Reservoir", fontsize=12)
    plt.ylabel("Temperature (°C)", fontsize=12)
    plt.xticks(rotation=45)
    plt.legend()
    plt.grid(True, linestyle="--", alpha=0.6)
    plt.show()

# %%
import folium
import pandas as pd

# Sample data simulating your full CSV dataset
data = [
    {"subdivision": "Almatti Reservoir", "storage": 120.5, "live_capacity_frl": 100.0},
    {"subdivision": "Bargi Reservoir", "storage": 95.0, "live_capacity_frl": 90.0},
    {"subdivision": "Hirakud Reservoir", "storage": 110.0, "live_capacity_frl": 100.0},
    {"subdivision": "Tehri Reservoir", "storage": 80.0, "live_capacity_frl": 120.0},
    {"subdivision": "Bhatsa Reservoir", "storage": 160.0, "live_capacity_frl": 100.0},
    {"subdivision": "Sardar Sarovar", "storage": 99.0, "live_capacity_frl": 100.0},
    {"subdivision": "Upper Vaitarna Reservoir", "storage": 105.0, "live_capacity_frl": 100.0},
    {"subdivision": "Indira Sagar", "storage": 102.0, "live_capacity_frl": 100.0},
    {"subdivision": "Nagarjuna Sagar", "storage": 89.0, "live_capacity_frl": 100.0},
    {"subdivision": "Idukki Reservoir", "storage": 70.0, "live_capacity_frl": 100.0},
    {"subdivision": "Krishnaraja Sagar", "storage": 101.0, "live_capacity_frl": 100.0},
    {"subdivision": "Ramganga Reservoir", "storage": 130.0, "live_capacity_frl": 100.0},
]

# Coordinates for each subdivision
reservoir_locations = {
    "Almatti Reservoir": (16.3386, 75.8864),
    "Bargi Reservoir": (22.9933, 79.8897),
    "Bhatsa Reservoir": (19.6944, 73.3217),
    "Hirakud Reservoir": (21.5456, 83.8724),
    "Sardar Sarovar": (21.8228, 73.7191),
    "Tehri Reservoir": (30.3831, 78.4800),
    "Upper Vaitarna Reservoir": (19.85, 73.52),
    "Indira Sagar": (22.2514, 76.4741),
    "Nagarjuna Sagar": (16.5733, 79.3186),
    "Idukki Reservoir": (9.8435, 76.9784),
    "Krishnaraja Sagar": (12.4220, 76.5717),
    "Ramganga Reservoir": (29.5964, 78.7530),
}

# Convert to DataFrame
df = pd.DataFrame(data)

# Calculate flood risk
df["flood_risk"] = df["storage"] / df["live_capacity_frl"]

# Create a map centered in India
flood_map = folium.Map(location=[22.0, 78.0], zoom_start=5)

# Add markers for all reservoirs
for _, row in df.iterrows():
    name = row['subdivision']
    risk = row['flood_risk']
    location = reservoir_locations.get(name, (22.0, 78.0))  # Default center if missing

    # Color by risk level
    if risk > 1.5:
        color = "red"
    elif risk > 1.0:
        color = "orange"
    else:
        color = "green"

    folium.CircleMarker(
        location=location,
        radius=8,
        popup=f"{name}<br>Flood Risk: {risk:.2f}",
        color=color,
        fill=True,
        fill_color=color
    ).add_to(flood_map)

# Display map (in Jupyter or similar)
flood_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
# ...
